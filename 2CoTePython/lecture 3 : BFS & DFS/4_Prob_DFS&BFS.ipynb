# %% [markdown]
# ##### <문제 1 : 음료수 얼려 먹기>
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ======================== <문제 1 해결 아이디어> ========================
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
