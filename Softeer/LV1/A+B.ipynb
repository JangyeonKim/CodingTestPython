# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def add(str_num) :
    a, b = map(int, str_num.split())
    return a+b 

num = int(input())

for i in range(num) :
    result = add(input())
    print(f"Case #{i+1}: {result}")
# Out:
# Case #1: 12
# Case #2: 5
# Case #3: 7
# Case #4: 17
# Case #5: 7
