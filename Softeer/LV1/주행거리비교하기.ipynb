# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
a, b = map(int, input().split())

if a > b :
    print("A")
elif a < b :
    print("B")
elif a==b :
    print("same")
# Out:
# A
