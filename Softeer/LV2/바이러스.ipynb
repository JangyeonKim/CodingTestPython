# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
K, P, N = map(int, input().split())

def cal_v(K, P, N) :
    
    num_v = K * (P ** N)

    return num_v % 1000000007

print(cal_v(K, P, N))
# Out:
# 18
